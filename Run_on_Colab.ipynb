# %% [markdown]
# # Context-aware BERT – ERC Nhóm 9 trên Colab (Dùng Github)
# Notebook hỗ trợ clone mã nguồn từ GitHub và chạy quá trình training bằng GPU miễn phí của Google Colab.
#
# **LƯU Ý:** Đảm bảo bạn đã bật GPU trên Colab: `Runtime` > `Change runtime type` > **T4 GPU** > `Save`.

# %%
# 1. Clone repository từ Github
# >>> VUI LÒNG ĐỔI ĐƯỜNG LINK BÊN DƯỚI THÀNH LINK REPO CỦA BẠN <<<
# !git clone https://github.com/trangdx2602/bert-context.git project_nhom9

# Di chuyển vào thư mục code
# %cd project_nhom9/Codebase

# 2. Cài đặt thư viện
# !pip install -r requirements.txt -q

# Kiểm tra GPU
import torch
print('GPU:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('Tên GPU:', torch.cuda.get_device_name(0))
else:
    print('\n⚠️ BẠN CHƯA BẬT GPU! Vui lòng chọn Runtime > Change runtime type > T4 GPU.')
# Out:
# Cloning into 'project_nhom9'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 29 (delta 4), reused 29 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 4.19 MiB | 9.11 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/project_nhom9/Codebase
# GPU: True
# Tên GPU: Tesla T4

# %% [markdown]
# ## 3. Huấn luyện mô hình (Training)

# %%
# Chạy bắt đầu huấn luyện với GPU (với context k = 3)
# Do GPU Colab T4 có 16GB VRAM, rất thoải mái dùng batch lớn.
# !python train.py --model bert_context --context_k 3 --batch_size 16 --accum_steps 2
# Out:
# ============================================================
#   Model            : bert_context
#   Context k        : 3
#   Device           : cuda
#   Mixed Precision  : ON
#   Batch size       : 16  (effective: 32)
#   Accum steps      : 2
#   Epochs           : 10
# ============================================================
#
# [1/4] Đang pre-tokenize và load dữ liệu...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 237kB/s]
# vocab.txt: 232kB [00:00, 8.08MB/s]
# tokenizer.json: 466kB [00:00, 8.75MB/s]
#   Đang pre-tokenize train...
#   Đang pre-tokenize val...
#   Đang pre-tokenize test...
#   Train: 9,989 samples
#   Val  : 1,109 samples
#
# [2/4] Class weights: ['0.303', '1.184', '5.325', '2.089', '0.819', '5.266', '1.287']
#
# [3/4] Load model...
# config.json: 100% 570/570 [00:00<00:00, 2.94MB/s]
# model.safetensors: 100% 440M/440M [00:05<00:00, 81.2MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 913.60it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#
# [4/4] Bắt đầu training...
#
# Epoch 1/10
#   Train → loss: 1.8033  F1: 0.3676  Acc: 0.3363
#   Val   → loss: 1.4966  F1: 0.4776  Acc: 0.4617
#   [Checkpoint saved] epoch=1, val_f1=0.4776 → /content/project_nhom9/Codebase/checkpoints/bert_context_k3_best.pt
# Epoch 2/10
#   Train → loss: 1.3854  F1: 0.5710  Acc: 0.5489
#   Val   → loss: 1.4318  F1: 0.5370  Acc: 0.5248
#   [Checkpoint saved] epoch=2, val_f1=0.5370 → /content/project_nhom9/Codebase/checkpoints/bert_context_k3_best.pt
# Epoch 3/10
#   Train → loss: 1.0403  F1: 0.6509  Acc: 0.6374
#   Val   → loss: 1.4391  F1: 0.5419  Acc: 0.5221
#   [Checkpoint saved] epoch=3, val_f1=0.5419 → /content/project_nhom9/Codebase/checkpoints/bert_context_k3_best.pt
# Epoch 4/10
#   Train → loss: 0.7236  F1: 0.7276  Acc: 0.7219
#   Val   → loss: 1.5514  F1: 0.5837  Acc: 0.5789
#   [Checkpoint saved] epoch=4, val_f1=0.5837 → /content/project_nhom9/Codebase/checkpoints/bert_context_k3_best.pt
# Epoch 5/10
#   Train → loss: 0.5172  F1: 0.7918  Acc: 0.7897
#   Val   → loss: 1.8579  F1: 0.5568  Acc: 0.5509
# Epoch 6/10
#   Train → loss: 0.3502  F1: 0.8438  Acc: 0.8429
#   Val   → loss: 1.9626  F1: 0.5827  Acc: 0.5816
# Epoch 7/10
#   Train → loss: 0.2554  F1: 0.8793  Acc: 0.8791
#   Val   → loss: 2.1423  F1: 0.5804  Acc: 0.5816
#
#   Early stopping tại epoch 7.
#
# Training xong! Checkpoint: /content/project_nhom9/Codebase/checkpoints/bert_context_k3_best.pt
# Best val F1 = 0.5837

# %% [markdown]
# ## 4. Đánh giá (Evaluation)

# %%
# Sau khi train xong, đánh giá kết quả trên tập test MELD
# !python evaluate.py --model bert_context --context_k 3
# Out:
# Device: cuda  |  AMP: ON
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#   Đang pre-tokenize train...
#   Đang pre-tokenize val...
#   Đang pre-tokenize test...
# Test set: 2,610 samples
#
# Loading weights: 100% 199/199 [00:00<00:00, 434.33it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#   [Checkpoint loaded] epoch=4, val_f1=0.5837
# Evaluating: 100% 164/164 [00:09<00:00, 17.03it/s]
#
# ============================================================
#   Model      : bert_context  (context_k=3)
#   Accuracy   : 0.5847
#   Weighted F1: 0.5965
# ============================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      neutral       0.78      0.67      0.72      1256
#     surprise       0.51      0.65      0.57       281
#         fear       0.10      0.30      0.15        50
#      sadness       0.33      0.33      0.33       208
#          joy       0.54      0.62      0.58       402
#      disgust       0.25      0.31      0.28        68
#        anger       0.52      0.42      0.46       345
#
#     accuracy                           0.58      2610
#    macro avg       0.43      0.47      0.44      2610
# weighted avg       0.62      0.58      0.60      2610
#
# Confusion Matrix (rows=true, cols=pred):
#          neut   surp   fear   sadn    joy   disg   ange
# neutral    847     73     66     87    116     22     45
# surpris     24    182     11      6     32      4     22
# fear        16      3     15      5      3      2      6
# sadness     57     13     23     68     18      8     21
# joy         70     26      6     17    249      9     25
# disgust     17      5      1      6      4     21     14
# anger       52     54     22     16     40     17    144
